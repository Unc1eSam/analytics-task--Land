# %%
# Импорт библиотек
import pandas as pd
import duckdb

# Задание таблиц БД
users = pd.read_csv('users.csv')
course_users = pd.read_csv('course_users.csv')
courses = pd.read_csv('courses.csv')
course_types = pd.read_csv('course_types.csv')
lessons = pd.read_csv('lessons.csv')
subjects = pd.read_csv('subjects.csv')
cities = pd.read_csv('cities.csv')
homework_done = pd.read_csv('homework_done.csv')
homework = pd.read_csv('homework.csv')
homework_lessons = pd.read_csv('homework_lessons.csv')
user_roles = pd.read_csv('user_roles.csv') 

# Задание SQL-запроса
query = """
-- CTE: Подсчет количества сданных ДЗ на курсе
WITH homework_counts AS (
    SELECT
        cu.user_id,
        cu.course_id,
        COUNT(hd.id) AS homework_done_count
    FROM course_users cu
    INNER JOIN homework_done hd ON cu.user_id = hd.user_id -- присоединяем таблицу с выполненными ДЗ
    INNER JOIN homework_lessons hl ON hd.homework_id = hl.homework_id -- присоединяем таблицу для того чтобы по ДЗ определить к какому уроку оно относится
    INNER JOIN lessons l ON hl.lesson_id = l.id AND l.course_id = cu.course_id -- по уроку определяем к какому курсу относится дз
    GROUP BY cu.user_id, cu.course_id -- группируем для подсчета количества
)

-- Основной запрос
SELECT
    cu.course_id AS "ID курса",                          
    c.name AS "Название курса",                       
    s.name AS "Предмет",                                
    s.project AS "Тип предмета",                        
    ct.name AS "Тип курса",                             
    c.starts_at AS "Дата старта курса",                 
    u.id AS "ID ученика",                              
    u.last_name AS "Фамилия ученика",                   
    ci.name AS "Город ученика",                        
    cu.active AS "Ученик не отчислен с курса",          
    cu.created_at AS "Дата открытия курса ученику",     
    FLOOR(cu.available_lessons / c.lessons_in_month) 
        AS "Количество открытых месяцев курса у ученика",  -- По логике количество доступных ученику занятий по курсу / количество занятий в месяц по курсу, с округлением вниз
    COALESCE(hc.homework_done_count, 0) 
        AS "Число сданных ДЗ ученика на курсе"          -- Количество выполненных ДЗ (с проверкой на NULL)
FROM course_users cu
JOIN users u ON cu.user_id = u.id
JOIN courses c ON cu.course_id = c.id
JOIN subjects s ON c.subject_id = s.id
JOIN course_types ct ON c.course_type_id = ct.id
JOIN cities ci ON u.city_id = ci.id
LEFT JOIN homework_counts hc -- Присоединяем слева для того, чтобы не отсечь учеников без выполненных ДЗ 
    ON cu.user_id = hc.user_id AND cu.course_id = hc.course_id
WHERE ct.name = 'Годовой' -- Фильтр по типу курса
  -- AND cu.active = 1  -- Фильтр: только активные ученики
GROUP BY 
    cu.course_id, c.name, s.name, s.project, ct.name, c.starts_at, 
    u.id, u.last_name, ci.name, cu.active, cu.created_at, 
    cu.available_lessons, c.lessons_in_month, hc.homework_done_count;
"""
df = duckdb.query(query).to_df()


# Вывод результата
display(df)
# Out:
#       ID курса                      Название курса             Предмет  \
# 0           18               Годовой 2к25 стандарт             История
# 1           19               Годовой 2к25 стандарт             Русский
# 2           19               Годовой 2к25 стандарт             Русский
# 3           16               Годовой 2к25 стандарт      Обществознание
# 4           19               Годовой 2к25 стандарт             Русский
# ...        ...                                 ...                 ...
# 5380        37                   Годовой курс 2к25         Русский ОГЭ
# 5381        19               Годовой 2к25 стандарт             Русский
# 5382        24  В погоне за пятеркой 2К25 стандарт   Математика (база)
# 5383        36                   Годовой курс 2к25  Обществознание ОГЭ
# 5384        23       Годовой 2К25 стандарт с Машей          Математика
#
#      Тип предмета Тип курса Дата старта курса  ID ученика Фамилия ученика  \
# 0             ЕГЭ   Годовой        2024-09-18       10035         Ерохина
# 1             ЕГЭ   Годовой        2024-09-21       10051      Третьякова
# 2             ЕГЭ   Годовой        2024-09-21       10365          Лысова
# 3             ЕГЭ   Годовой        2024-09-16       10374          Быкова
# 4             ЕГЭ   Годовой        2024-09-21       10414           Пищик
# ...           ...       ...               ...         ...             ...
# 5380          ОГЭ   Годовой        2024-09-25       10338         Иванова
# 5381          ЕГЭ   Годовой        2024-09-21       10661         Кулигин
# 5382          ЕГЭ   Годовой        2024-09-17       30180        Могилева
# 5383          ОГЭ   Годовой        2024-09-30       33254     Крачковская
# 5384          ЕГЭ   Годовой        2024-09-20       33554         Kovalik
#
#          Город ученика  Ученик не отчислен с курса  \
# 0              Ангарск                           1
# 1               Тотьма                           1
# 2      Нижний Новгород                           1
# 3               Москва                           1
# 4            Краснодар                           1
# ...                ...                         ...
# 5380            Ачинск                           0
# 5381        Красноярск                           0
# 5382       Новосибирск                           1
# 5383          Кемерово                           0
# 5384  Советская Гавань                           1
#
#      Дата открытия курса ученику  Количество открытых месяцев курса у ученика  \
# 0            2024-08-11 13:25:28                                          3.0
# 1            2024-07-26 18:50:03                                          1.0
# 2            2024-07-30 20:01:27                                          1.0
# 3            2024-09-19 10:57:47                                          2.0
# 4            2024-08-22 18:38:01                                          2.0
# ...                          ...                                          ...
# 5380         2024-07-30 16:14:21                                          0.0
# 5381         2024-08-02 12:11:38                                          0.0
# 5382         2024-10-06 16:02:35                                          2.0
# 5383         2024-10-10 15:19:43                                          1.0
# 5384         2024-10-11 06:16:43                                          1.0
#
#       Число сданных ДЗ ученика на курсе
# 0                                    16
# 1                                     8
# 2                                     7
# 3                                     8
# 4                                    14
# ...                                 ...
# 5380                                  0
# 5381                                  0
# 5382                                  0
# 5383                                  0
# 5384                                  0
#
# [5385 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5385 entries, 0 to 5384
# Data columns (total 13 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   ID курса                                     5385 non-null   int64
#  1   Название курса                               5385 non-null   object
#  2   Предмет                                      5385 non-null   object
#  3   Тип предмета                                 5385 non-null   object
#  4   Тип курса                                    5385 non-null   object
#  5   Дата старта курса                            5385 non-null   object
#  6   ID ученика                                   5385 non-null   int64
#  7   Фамилия ученика                              5385 non-null   object
#  8   Город ученика                                5385 non-null   object
#  9   Ученик не отчислен с курса                   5385 non-null   int64
#  10  Дата открытия курса ученику                  5385 non-null   object
#  11  Количество открытых месяцев курса у ученика  5370 non-null   float64
#  12  Число сданных ДЗ ученика на курсе            5385 non-null   int64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 547.0+ KB

# %% [markdown]
# #### 1.Проверим форматы данных
#
# - Преобразуем строковые даты в datetime и столбец `Количество открытых месяцев курса у ученика` в целочисленное

# %%
df["Дата старта курса"] = pd.to_datetime(df["Дата старта курса"], errors="coerce")
df["Дата открытия курса ученику"] = pd.to_datetime(df["Дата открытия курса ученику"], errors="coerce")
df["Количество открытых месяцев курса у ученика"] = df["Количество открытых месяцев курса у ученика"].astype("Int64")

# %% [markdown]
# #### 2.Проверим данные на пропуски
#
# - Посчитаем сумму пропущенных значений по столбцам и проанализируем их

# %%
df.isna().sum() #Вывод суммы пропусков по столбцам
# Out:
# ID курса                                        0
# Название курса                                  0
# Предмет                                         0
# Тип предмета                                    0
# Тип курса                                       0
# Дата старта курса                               0
# ID ученика                                      0
# Фамилия ученика                                 0
# Город ученика                                   0
# Ученик не отчислен с курса                      0
# Дата открытия курса ученику                     0
# Количество открытых месяцев курса у ученика    15
# Число сданных ДЗ ученика на курсе               0
# dtype: int64

# %%
df_with_misses = df[df.isna().any(axis=1)] #вывод строк с пропущенными значениями 
df_with_misses
# Out:
#       ID курса                                     Название курса  \
# 625         73  Годовой курс 2к25 комбо (биология + русский + ...
# 654         39  Годовой курс 2к25 комбо (русский + обществозна...
# 1272        74  Годовой курс 2к25 комбо (биология + обществозн...
# 1940        39  Годовой курс 2к25 комбо (русский + обществозна...
# 1964        39  Годовой курс 2к25 комбо (русский + обществозна...
# 2622        39  Годовой курс 2к25 комбо (русский + обществозна...
# 2678        74  Годовой курс 2к25 комбо (биология + обществозн...
# 3306        39  Годовой курс 2к25 комбо (русский + обществозна...
# 3325        39  Годовой курс 2к25 комбо (русский + обществозна...
# 3349        39  Годовой курс 2к25 комбо (русский + обществозна...
# 4024        39  Годовой курс 2к25 комбо (русский + обществозна...
# 4029        39  Годовой курс 2к25 комбо (русский + обществозна...
# 4031        39  Годовой курс 2к25 комбо (русский + обществозна...
# 4697        74  Годовой курс 2к25 комбо (биология + обществозн...
# 5371        39  Годовой курс 2к25 комбо (русский + обществозна...
#
#                  Предмет Тип предмета Тип курса Дата старта курса  ID ученика  \
# 625          Русский ОГЭ          ОГЭ   Годовой        2024-09-22       30273
# 654   Обществознание ОГЭ          ОГЭ   Годовой        2024-09-15       28539
# 1272  Обществознание ОГЭ          ОГЭ   Годовой        2024-09-22       28327
# 1940  Обществознание ОГЭ          ОГЭ   Годовой        2024-09-15       25975
# 1964  Обществознание ОГЭ          ОГЭ   Годовой        2024-09-15       30135
# 2622  Обществознание ОГЭ          ОГЭ   Годовой        2024-09-15       25219
# 2678  Обществознание ОГЭ          ОГЭ   Годовой        2024-09-22       30965
# 3306  Обществознание ОГЭ          ОГЭ   Годовой        2024-09-15       28200
# 3325  Обществознание ОГЭ          ОГЭ   Годовой        2024-09-15       28420
# 3349  Обществознание ОГЭ          ОГЭ   Годовой        2024-09-15       28914
# 4024  Обществознание ОГЭ          ОГЭ   Годовой        2024-09-15       30369
# 4029  Обществознание ОГЭ          ОГЭ   Годовой        2024-09-15       28071
# 4031  Обществознание ОГЭ          ОГЭ   Годовой        2024-09-15       30473
# 4697  Обществознание ОГЭ          ОГЭ   Годовой        2024-09-22       28458
# 5371  Обществознание ОГЭ          ОГЭ   Годовой        2024-09-15       28022
#
#      Фамилия ученика Город ученика  Ученик не отчислен с курса  \
# 625        Петросова        Москва                           1
# 654         Зацепина        Тюмень                           1
# 1272          Юшкова         Серов                           1
# 1940             Aix     Краснодар                           1
# 1964       Подгузова        Рязань                           1
# 2622           Лысов     Хабаровск                           1
# 2678        Таськина        Липецк                           1
# 3306         Chukhno       Когалым                           1
# 3325      Губейдулин        Мытищи                           1
# 3349             Цып  Великие Луки                           1
# 4024               Z        Москва                           1
# 4029          Павлов   Архангельск                           1
# 4031         Пальчун         Курск                           1
# 4697      Вакуликова      Волжский                           1
# 5371          Зотова     Челябинск                           1
#
#      Дата открытия курса ученику  Количество открытых месяцев курса у ученика  \
# 625          2024-10-01 19:25:57                                         <NA>
# 654          2024-09-25 13:33:15                                         <NA>
# 1272         2024-09-24 15:58:00                                         <NA>
# 1940         2024-10-24 14:12:31                                         <NA>
# 1964         2024-10-01 14:27:08                                         <NA>
# 2622         2024-09-16 13:45:20                                         <NA>
# 2678         2024-10-03 18:51:12                                         <NA>
# 3306         2024-09-24 09:05:46                                         <NA>
# 3325         2024-09-24 19:37:32                                         <NA>
# 3349         2024-09-26 21:12:10                                         <NA>
# 4024         2024-10-03 05:11:24                                         <NA>
# 4029         2024-09-25 07:17:49                                         <NA>
# 4031         2024-10-03 15:07:00                                         <NA>
# 4697         2024-09-25 08:18:00                                         <NA>
# 5371         2024-09-23 15:16:39                                         <NA>
#
#       Число сданных ДЗ ученика на курсе
# 625                                   0
# 654                                   0
# 1272                                  0
# 1940                                  0
# 1964                                  0
# 2622                                  0
# 2678                                  0
# 3306                                  0
# 3325                                  0
# 3349                                  0
# 4024                                  0
# 4029                                  0
# 4031                                  0
# 4697                                  0
# 5371                                  0

# %% [markdown]
# - Оценим ситуацию, проверим пропуски на предмет возникновения. Узнаем зависят ли они от курса, предмета, типа предмета или же пропуски вовсе случайны.

# %%
display(df_with_misses['ID курса'].value_counts()) # группировка пропусков по признакам
display(df_with_misses['Предмет'].value_counts())
display(df_with_misses['Тип предмета'].value_counts())
# Out:
# ID курса
# 39    11
# 74     3
# 73     1
# Name: count, dtype: int64
# Предмет
# Обществознание ОГЭ    14
# Русский ОГЭ            1
# Name: count, dtype: int64
# Тип предмета
# ОГЭ    15
# Name: count, dtype: int64

# %%
display(df['ID курса'].value_counts()) # Общее количество значений по признакам
display(df['Предмет'].value_counts())
display(df['Тип предмета'].value_counts())
# Out:
# ID курса
# 16    1652
# 19     856
# 22     426
# 17     391
# 23     380
# 18     355
# 25     271
# 24     167
# 36     155
# 38     151
# 37     133
# 21     129
# 41     108
# 20     104
# 42      48
# 39      22
# 56      14
# 59       9
# 57       5
# 74       3
# 79       2
# 62       1
# 73       1
# 81       1
# 80       1
# Name: count, dtype: int64
# Предмет
# Обществознание        1668
# Русский                865
# Математика             488
# Литература             427
# Английский язык        397
# История                356
# Биология               271
# Обществознание ОГЭ     180
# Математика (база)      167
# Математика ОГЭ         151
# Русский ОГЭ            134
# Химия                  129
# Физика                 104
# Биология ОГЭ            48
# Name: count, dtype: int64
# Тип предмета
# ЕГЭ    4872
# ОГЭ     513
# Name: count, dtype: int64

# %% [markdown]
# Корреляции между курсом, предметом, типом предметом и пропусками не наблюдается, но можно сделать некоторые выводы, которые могут быть полезны специалистам по данным
# - На курсе с ID = 39 , 11 из 22 учеников имеют пропуски в количестве доступных уроков
# - На крусах 73 и 74, такая ситуация у всех обучающихся, но выборка мала для каких - либо выводов - суммарно 4 человека
#
# Так как пропуски занимают незначительное количество от общего количества и по курсам 73 и 74 сложно будет получить информацию, которая требуется при дальнейшем анализе, то удалим строки с пропусками значений.

# %%
df = df.dropna()

# %% [markdown]
# #### 3. Проверка данных на наличие дубликатов и числовых аномалий

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print("\nУникальные значения в категориальных столбцах:")
for column in df.select_dtypes(include=['object']).columns: #Проходимся по столбцам с типом 'object' и выводим их уникальные значения
    print(f"\n{column}:")
    display(df[column].unique())
# Out:
# Уникальные значения в категориальных столбцах:
#
# Название курса:
# array(['Годовой 2к25 стандарт', 'В погоне за пятеркой 2К25 стандарт',
#        'Годовой курс 2к25', 'Годовой 2к25 платинум',
#        'Годовой 2К25 стандарт с Машей', 'Годовой 2К25 стандарт с Катей',
#        'Годовой 2к25 минимал',
#        'Годовой курс 2к25 комбо (русский + обществознание + математика)'],
#       dtype=object)
# Предмет:
# array(['История', 'Русский', 'Обществознание', 'Английский язык',
#        'Математика (база)', 'Литература', 'Биология',
#        'Обществознание ОГЭ', 'Математика', 'Биология ОГЭ', 'Химия',
#        'Математика ОГЭ', 'Русский ОГЭ', 'Физика'], dtype=object)
# Тип предмета:
# array(['ЕГЭ', 'ОГЭ'], dtype=object)
# Тип курса:
# array(['Годовой'], dtype=object)
# Фамилия ученика:
# array(['Ерохина', 'Третьякова', 'Лысова', ..., 'Башина', 'Козырева',
#        'Хоперскова'], dtype=object)
# Город ученика:
# array(['Ангарск', 'Тотьма', 'Нижний Новгород', 'Москва', 'Краснодар',
#        'Казань', 'Калуга', 'Республика Дагестанские Огни', 'Владивосток',
#        'Кодинск', 'Йошкар-Ола', 'Подольск', 'Брянск', 'Красноярск',
#        'Ханты-Мансийск', 'Санкт-Петербург', 'Олонец', 'Тверь', 'Тула',
#        'Волгоград', 'Липецк', 'Ноябрьск', 'Одинцово', 'Ростов-на-Дону',
#        'Ставрополь', 'Бирск', 'Ртищево', 'Апшеронск', 'Избербаш',
#        'Иркутск', 'Кемерово', 'Новосибирск', 'Люберцы', 'Раменское',
#        'Всеволожск', 'Архангельск', 'Ельня', 'Сергиев Посад',
#        'Владикавказ', 'Видное', 'Ковров', 'Прокопьевск', 'Ейск', 'Самара',
#        'Киров', 'Каменск-Уральский', 'Кропоткин', 'Барнаул', 'Ижевск',
#        'Верхняя Салда', 'Хабаровск', 'Норильск', 'Моршанск', 'Орёл',
#        'Балтийск', 'Ессентуки', 'Канаш', 'Альметьевск', 'Темрюк',
#        'Орехово-Зуево', 'Ахтубинск', 'Минеральные Воды', 'Тольятти',
#        'Омск', 'Новокузнецк', 'Северодвинск', 'Домодедово', 'Тамбов',
#        'Вязники', 'Тосно', 'Завитинск', 'Туймазы', 'Чебоксары', 'Тайшет',
#        'Феодосия', 'Ростов', 'Стерлитамак', 'Руза', 'Саратов',
#        'Черняховск', 'Находка', 'Сочи', 'Курск', 'Первоуральск',
#        'Благовещенск', 'Тюмень', 'Волоколамск', 'Челябинск', 'Уфа',
#        'Элиста', 'Махачкала', 'Рязань', 'Холмск', 'Калининград',
#        'Оренбург', 'Курган', 'Ершов', 'Луза', 'Карасук', 'Череповец',
#        'Аксай', 'Туапсе', 'Балашиха', 'Озёрск', 'Сватово', 'Красногорск',
#        'Балабаново', 'Щёлково', 'Зеленогорск', 'Петропавловск-Камчатский',
#        'Мытищи', 'Иваново', 'Владимир', 'Комсомольск-на-Амуре',
#        'Улан-Удэ', 'Волжск', 'Маркс', 'Шали', 'Набережные Челны',
#        'Богородицк', 'Новый Уренгой', 'Орск', 'Жуковский', 'Североморск',
#        'Белгород', 'Салават', 'Астрахань', 'Павлово', 'Новороссийск',
#        'Яхрома', 'Донецк', 'Ульяновск', 'Белорецк', 'Чита',
#        'Новомосковск', 'Сызрань', 'Великие Луки', 'Сыктывкар',
#        'Лабытнанги', 'Саранск', 'Мирный', 'Пушкино', 'Новочеркасск',
#        'Славгород', 'Ленск', 'Евпатория', 'Болгар', 'Пенза', 'Тутаев',
#        'Салехард', 'Долгопрудный', 'Энгельс', 'Ступино', 'Ломоносов',
#        'Мончегорск', 'Магадан', 'Нижняя Тура', 'Наро-Фоминск',
#        'Александровск', 'Якутск', 'Псков', 'Корсаков', 'Елизово',
#        'Михайловка', 'Пушкин', 'Воронеж', 'Ярославль', 'Елабуга',
#        'Верхотурье', 'Десногорск', 'Рыбинск', 'Мариинск', 'Сургут',
#        'Реутов', 'Щёкино', 'Ялуторовск', 'Каменск-Шахтинский', 'Отрадное',
#        'Камышлов', 'Екатеринбург', 'Обнинск', 'Волжский', 'Ивантеевка',
#        'Нурлат', 'Нижнекамск', 'Зеленокумск', 'Камышин', 'Саяногорск',
#        'Таштагол', 'Дзержинский', 'Новоаннинский', 'Бронницы', 'Луховицы',
#        'Майкоп', 'Дербент', 'Междуреченск', 'Гудермес', 'Ногинск',
#        'Валдай', 'Братск', 'Губкин', 'Короча', 'Симферополь',
#        'Лениногорск', 'Дзержинск', 'Анапа', 'Черемхово', 'Менделеевск',
#        'Шебекино', 'Суворов', 'Коломна', 'Кострома', 'Берёзовский',
#        'Михайлов', 'Сарапул', 'Воскресенск', 'Волгодонск', 'Электроугли',
#        'Серов', 'Саки', 'Суздаль', 'Химки', 'Севастополь', 'Нальчик',
#        'Нижневартовск', 'Азов', 'Ревда', 'Пермь', 'Очёр', 'Кондопога',
#        'Киселёвск', 'Томск', 'Емва', 'Солнечногорск', 'Ишимбай',
#        'Павловск', 'Надым', 'Бирюч', 'Иланский', 'Кораблино', 'Уссурийск',
#        'Чистополь', 'Смоленск', 'Тында', 'Моздок', 'Клин', 'Асбест',
#        'Нелидово', 'Сорочинск', 'Бугульма', 'Коркино', 'Отрадный',
#        'Куйбышев', 'Нефтеюганск', 'Выборг', 'Новочебоксарск',
#        'Славянск-на-Кубани', 'Горно-Алтайск', 'Кстово', 'Армавир',
#        'Дальнереченск', 'Борисоглебск', 'Азнакаево', 'Глазов',
#        'Сосновоборск', 'Зеленодольск', 'Урень', 'Изобильный', 'Когалым',
#        'Серпухов', 'Искитим', 'Алушта', 'Арзамас', 'Агидель', 'Бабаево',
#        'Хвалынск', 'Кушва', 'Вельск', 'Усть-Лабинск', 'Бердянск\r',
#        'Онега', 'Сосновый Бор', 'Каменногорск', 'Абакан', 'Калтан',
#        'Донецк\r', 'Усть-Катав', 'Димитровград', 'Вологда', 'Чулым',
#        'Королёв', 'Нерюнгри', 'Новокубанск', 'Богучар', 'Бердск',
#        'Петрозаводск', 'Анива', 'Сестрорецк', 'Партизанск', 'Городец',
#        'Юрга', 'Сегежа', 'Кунгур', 'Троицк', 'Черногорск', 'Сысерть',
#        'Октябрьский', 'Тобольск', 'Заринск', 'Коряжма', 'Кузнецк',
#        'Белово', 'Пыть-Ях', 'Нефтекамск', 'Белебей', 'Ряжск',
#        'Североуральск', 'Бор', 'Кремёнки', 'Сосногорск', 'Мыски',
#        'Ленинск-Кузнецкий', 'Карталы', 'Великий Новгород', 'Поворино',
#        'Чернушка', 'Суджа', 'Кореновск', 'Алексин', 'Слободской',
#        'Кандалакша', 'Минусинск', 'Мурманск', 'Дмитров', 'Енисейск',
#        'Янаул', 'Рошаль', 'Змеиногорск', 'Будённовск', 'Полысаево',
#        'Мценск', 'Вышний Волочёк', 'Усть-Кут', 'Сафоново', 'Сальск',
#        'Бийск', 'Старая Русса', 'Фокино', 'Ухта', 'Рыбное', 'Новоуральск',
#        'Питкяранта', 'Белогорск', 'Алдан', 'Кашира', 'Ровеньки\r',
#        'Гулькевичи', 'Белокуриха', 'Шахты', 'Чапаевск',
#        'Советская Гавань', 'Пугачёв', 'Дальнегорск', 'Миллерово',
#        'Аркадак', 'Плавск', 'Усть-Джегута', 'Советск', 'Лангепас',
#        'Лабинск', 'Саянск', 'Стародуб', 'Губкинский', 'Чкаловск',
#        'Южно-Сахалинск', 'Родники', 'Горняк', 'Верхняя Пышма', 'Джанкой',
#        'Вятские Поляны', 'Черкесск', 'Ирбит', 'Чебаркуль', 'Стрежевой',
#        'Копейск', 'Приморско-Ахтарск', 'Арск', 'Таганрог', 'Нижний Тагил',
#        'Туран', 'Талдом', 'Анжеро-Судженск', 'Володарск',
#        'Новокуйбышевск', 'Егорьевск', 'Дигора', 'Жигулёвск', 'Сортавала',
#        'Муравленко', 'Краснотурьинск', 'Дмитриев', 'Югорск',
#        'Краснодон\r', 'Баксан', 'Ачинск', 'Кумертау', 'Фрязино',
#        'Жердевка', 'Балаково', 'Сокол', 'Лукоянов', 'Кольчугино', 'Аша',
#        'Яровое', 'Миасс', 'Осинники', 'Макаров', 'Оха', 'Мелеуз',
#        'Кириши', 'Артём', 'Апатиты', 'Обоянь', 'Кингисепп', 'Звенигород',
#        'Карабулак', 'Андреаполь', 'Нягань', 'Курганинск',
#        'Краснознаменск', 'Рузаевка', 'Куровское', 'Кызыл', 'Полевской',
#        'Кизляр', 'Республика Крымск', 'Михайловск', 'Калининск', 'Кинель',
#        'Тарко-Сале', 'Зеленоградск', 'Новомичуринск', 'Электросталь',
#        'Невельск', 'Лесосибирск', 'Лобня', 'Южа', 'Новодвинск',
#        'Великий Устюг', 'Пущино', 'Дмитровск', 'Николаевск-на-Амуре',
#        'Могоча', 'Южноуральск', 'Краснокаменск', 'Белореченск',
#        'Лебедянь', 'Спасск-Дальний', 'Ишим', 'Шагонар', 'Котельнич',
#        'Гуково', 'Узловая', 'Буй', 'Назрань', 'Вольск', 'Знаменск',
#        'Омутнинск', 'Кохма', 'Волхов', 'Гагарин', 'Катав-Ивановск',
#        'Бугуруслан', 'Истра', 'Можга', 'Агрыз', 'Зарайск', 'Выкса',
#        'Семёнов', 'Калач-на-Дону', 'Слюдянка', 'Колпашево', 'Балахна',
#        'Ликино-Дулёво', 'Уварово', 'Среднеуральск', 'Комсомольск',
#        'Невинномысск', 'Боровичи', 'Новохопёрск', 'Поронайск',
#        'Геленджик', 'Малоярославец', 'Дорогобуж', 'Чехов', 'Хасавюрт',
#        'Рудня', 'Муром', 'Саров', 'Кировск', 'Шелехов', 'Шумерля',
#        'Каспийск', 'Рубцовск', 'Старый Оскол', 'Белинский', 'Пятигорск',
#        'Морозовск', 'Россошь', 'Кисловодск', 'Белоярский', 'Магнитогорск',
#        'Новый Оскол', 'Мензелинск', 'Заозёрск', 'Цивильск', 'Биробиджан',
#        'Каменка', 'Мариинский Посад', 'Адыгейск', 'Няндома', 'Гатчина',
#        'Нижнеудинск', 'Барабинск', 'Усинск', 'Краснослободск', 'Гурьевск',
#        'Железногорск', 'Бавлы', 'Семикаракорск', 'Ясный', 'Гай',
#        'Макеевка\r', 'Лиски', 'Верхний Уфалей', 'Заинск', 'Советский',
#        'Судак', 'Красноармейск', 'Новоалександровск', 'Назарово',
#        'Рославль', 'Вязьма', 'Радужный', 'Обь', 'Дятьково', 'Весьегонск',
#        'Касли', 'Елец', 'Уяр', 'Мариуполь\r', 'Мичуринск', 'Беслан',
#        'Шахунья', 'Лакинск', 'Фролово', 'Снежное\r', 'Клинцы', 'Сланцы',
#        'Алексеевка', 'Медногорск', 'Кяхта', 'Лыткарино', 'Калач',
#        'Коммунар', 'Воркута', 'Курчатов', 'Пионерский', 'Учалы',
#        'Горнозаводск', 'Ипатово', 'Жуковка', 'Кубинка', 'Ковылкино',
#        'Новотроицк'], dtype=object)

# %% [markdown]
# Полные дубликаты, а также неявные дубликаты в категориальных столбцах отсутствуют

# %%
df.describe() # Описательная статистика по числовым столбцам
# Out:
#           ID курса              Дата старта курса    ID ученика  \
# count  5370.000000                           5370   5370.000000
# mean     21.324022  2024-09-19 04:59:31.843575552  24584.787151
# min      16.000000            2024-09-15 00:00:00  10001.000000
# 25%      16.000000            2024-09-16 00:00:00  10980.250000
# 50%      19.000000            2024-09-17 00:00:00  28293.000000
# 75%      23.000000            2024-09-21 00:00:00  30577.000000
# max      81.000000            2024-10-15 00:00:00  33999.000000
# std       7.401306                            NaN   8651.624755
#
#        Ученик не отчислен с курса    Дата открытия курса ученику  \
# count                 5370.000000                           5370
# mean                     0.943389  2024-09-17 20:59:51.596089600
# min                      0.000000            2024-07-25 18:04:20
# 25%                      1.000000            2024-09-16 12:44:47
# 50%                      1.000000            2024-09-25 19:32:34
# 75%                      1.000000            2024-10-06 09:13:21
# max                      1.000000            2024-11-09 18:44:36
# std                      0.231119                            NaN
#
#        Количество открытых месяцев курса у ученика  \
# count                                       5370.0
# mean                                      2.216574
# min                                            0.0
# 25%                                            2.0
# 50%                                            2.0
# 75%                                            2.0
# max                                           10.0
# std                                       1.722136
#
#        Число сданных ДЗ ученика на курсе
# count                         5370.00000
# mean                            10.31676
# min                              0.00000
# 25%                              5.00000
# 50%                             10.00000
# 75%                             15.00000
# max                             34.00000
# std                              6.92592

# %% [markdown]
# Аномалии в числовых значениях остуствуют

# %% [markdown]
# #### 4.Распределим учеников по волнам
#
# - Создадим столбец `Волна`, который будет рассчитываться на основе разницы дней дат открытия курса ученик и старта курса.
# - К этой разнице прибавим 6 и целочисленно поделим на 7, что и будет давать нам номер волны.
# - Также ограничимся минимальными значениями в 0 и 5 и добавим в конец строку 'Волна'

# %%
df['Волна'] = (((df['Дата открытия курса ученику'] - df['Дата старта курса']).dt.days + 6) // 7).clip(lower=0, upper=5).astype(str) + ' волна'

# %%
df
# Out:
#       ID курса                      Название курса             Предмет  \
# 0           18               Годовой 2к25 стандарт             История
# 1           19               Годовой 2к25 стандарт             Русский
# 2           19               Годовой 2к25 стандарт             Русский
# 3           16               Годовой 2к25 стандарт      Обществознание
# 4           19               Годовой 2к25 стандарт             Русский
# ...        ...                                 ...                 ...
# 5380        37                   Годовой курс 2к25         Русский ОГЭ
# 5381        19               Годовой 2к25 стандарт             Русский
# 5382        24  В погоне за пятеркой 2К25 стандарт   Математика (база)
# 5383        36                   Годовой курс 2к25  Обществознание ОГЭ
# 5384        23       Годовой 2К25 стандарт с Машей          Математика
#
#      Тип предмета Тип курса Дата старта курса  ID ученика Фамилия ученика  \
# 0             ЕГЭ   Годовой        2024-09-18       10035         Ерохина
# 1             ЕГЭ   Годовой        2024-09-21       10051      Третьякова
# 2             ЕГЭ   Годовой        2024-09-21       10365          Лысова
# 3             ЕГЭ   Годовой        2024-09-16       10374          Быкова
# 4             ЕГЭ   Годовой        2024-09-21       10414           Пищик
# ...           ...       ...               ...         ...             ...
# 5380          ОГЭ   Годовой        2024-09-25       10338         Иванова
# 5381          ЕГЭ   Годовой        2024-09-21       10661         Кулигин
# 5382          ЕГЭ   Годовой        2024-09-17       30180        Могилева
# 5383          ОГЭ   Годовой        2024-09-30       33254     Крачковская
# 5384          ЕГЭ   Годовой        2024-09-20       33554         Kovalik
#
#          Город ученика  Ученик не отчислен с курса  \
# 0              Ангарск                           1
# 1               Тотьма                           1
# 2      Нижний Новгород                           1
# 3               Москва                           1
# 4            Краснодар                           1
# ...                ...                         ...
# 5380            Ачинск                           0
# 5381        Красноярск                           0
# 5382       Новосибирск                           1
# 5383          Кемерово                           0
# 5384  Советская Гавань                           1
#
#      Дата открытия курса ученику  Количество открытых месяцев курса у ученика  \
# 0            2024-08-11 13:25:28                                            3
# 1            2024-07-26 18:50:03                                            1
# 2            2024-07-30 20:01:27                                            1
# 3            2024-09-19 10:57:47                                            2
# 4            2024-08-22 18:38:01                                            2
# ...                          ...                                          ...
# 5380         2024-07-30 16:14:21                                            0
# 5381         2024-08-02 12:11:38                                            0
# 5382         2024-10-06 16:02:35                                            2
# 5383         2024-10-10 15:19:43                                            1
# 5384         2024-10-11 06:16:43                                            1
#
#       Число сданных ДЗ ученика на курсе    Волна
# 0                                    16  0 волна
# 1                                     8  0 волна
# 2                                     7  0 волна
# 3                                     8  1 волна
# 4                                    14  0 волна
# ...                                 ...      ...
# 5380                                  0  0 волна
# 5381                                  0  0 волна
# 5382                                  0  3 волна
# 5383                                  0  2 волна
# 5384                                  0  3 волна
#
# [5370 rows x 14 columns]
